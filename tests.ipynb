# %%
from fastText import FastText

# %%
model = FastText.load_model('data/cc.ru.300.bin')

# %%
word1 = model.get_sentence_vector('чинить розетка')
word.shape
# Out:
# (300,)

# %%
word2 = model.get_sentence_vector('чинить проводка')
word.shape
# Out:
# (300,)

# %%
word1
# Out:
# array([ 0.07633191, -0.06760906,  0.02774587,  0.02873608,  0.05105841,
#        -0.07549532, -0.02122899,  0.03813405, -0.0016287 , -0.02162213,
#        -0.04165189, -0.03732203,  0.0256254 ,  0.04854685,  0.02223372,
#         0.00854601,  0.0687621 , -0.01440719,  0.02014861,  0.08045794,
#        -0.03472584,  0.00722685,  0.0321744 ,  0.00108667,  0.02858754,
#        -0.01830264, -0.02862267, -0.00769462,  0.04093672,  0.0304191 ,
#         0.03785327, -0.1043817 , -0.0341    ,  0.01106412, -0.01172909,
#         0.03632371,  0.06345762, -0.09825879, -0.03308397,  0.03421361,
#        -0.02979825, -0.04087572, -0.01402968,  0.03371323,  0.04150418,
#        -0.02707998,  0.04059561, -0.10162915,  0.08698038,  0.11418934,
#         0.06337602,  0.05028172,  0.0231045 ,  0.001611  , -0.08563783,
#        -0.04392105,  0.03671662, -0.02529932, -0.03222878,  0.04310273,
#        -0.01614681,  0.0759038 , -0.08675738,  0.01196853,  0.04238941,
# ...

# %%
word2
# Out:
# array([ 0.00270216, -0.08299399,  0.07924801,  0.04220598, -0.05151409,
#        -0.06094449, -0.0058438 ,  0.01463888, -0.05907705, -0.01871327,
#        -0.03545553, -0.03375405,  0.02580373,  0.02705406,  0.01251231,
#         0.05977455,  0.07682038,  0.0472407 ,  0.01249785,  0.05687726,
#        -0.06147862, -0.02282626, -0.02099949,  0.02392554,  0.03102723,
#         0.05833954, -0.00330987, -0.00019601, -0.0063203 ,  0.02475867,
#         0.03374001, -0.0368569 , -0.0940293 , -0.03644498,  0.00673173,
#         0.01187601,  0.07632446, -0.09750818, -0.04445845,  0.0046708 ,
#         0.02627493, -0.02704157, -0.05124269,  0.01993277,  0.0202119 ,
#        -0.01312622,  0.03190074, -0.03003716,  0.07098182,  0.08417878,
#         0.04277952,  0.03250221,  0.00904234,  0.00092345, -0.04124245,
#        -0.06831221, -0.02056159, -0.03180609, -0.01971861,  0.02018036,
#        -0.01303645,  0.02680028, -0.0188971 ,  0.0459525 , -0.01737497,
# ...

# %%
model.f.getVocab('розетка')
# Out:
# ([',',
#   '.',
#   'и',
#   'в',
#   '</s>',
#   ':',
#   ')',
#   '(',
#   'на',
#   '"',
#   'с',
#   'не',
#   '»',
#   'для',
#   '-',
#   '«',
#   '/',
#   'по',
#   '—',
#   'что',
#   'В',
#   '!',
#   'из',
#   'от',
#   'к',
#   'как',
#   '?',
#   'а',
#   '–',
#   'за',
#   ';',
#   'о',
#   'или',
#   'это',
#   '�',
#   '1',
#   '...',
#   '_',
#   "'",
#   'его',
#   'у',
#   'до',
#   '|',
#   '2',
#   'но',
#   'все',
#   'года',
#   '+',
#   'я',
#   'то',
#   '%',
#   'при',
#   'он',
#   'так',
#   'же',
#   'только',
#   '3',
#   'их',
#   'А',
#   'можно',
#   '#',
#   'был',
#   'И',
#   'время',
#   'также',
#   'году',
#   '10',
#   'было',
#   'будет',
#   'может',
#   'вы',
#   '0',
#   'уже',
#   '[',
#   ']',
#   '4',
#   '>',
#   'чтобы',
#   'есть',
#   'На',
#   'если',
#   '5',
#   '…',
#   'г',
#   'которые',
#   'С',
#   'без',
#   'со',
#   'очень',
#   'бы',
#   'мы',
#   'этом',
#   'более',
#   'под',
#   'они',
#   'быть',
#   'России',
# ...
